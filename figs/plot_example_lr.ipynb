# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lr=np.load("example_lr.npy")
plt.plot(lr, linewidth=1)
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("learning rate")
plt.savefig("example_lr.png")
